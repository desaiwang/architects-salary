# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/250.9 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 3.1 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\desai\.conda\envs\4620-a3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\desai\.conda\envs\4620-a3\lib\site-packages)

# %%
df_fulltime = pd.read_csv('241209_archinect_salaries_fulltime.csv')

# %%
df = pd.read_excel("ABI Data - February 19, 2025 Release.xlsx", "ABI_National")

# %%
df = pd.read_excel("ABI Data - February 19, 2025 Release.xlsx", "ABI_National", header=4, usecols=[0, 1, 2, 3])
df = df.iloc[:-4]

# %%
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)
df[['Billings', 'Inquiries', 'Design Contracts']].plot(figsize=(12, 6))
plt.xlabel('Month')
plt.ylabel('Values')
plt.title('Billings, Inquiries, and Design Contracts Over Time')
plt.legend()
plt.show()
